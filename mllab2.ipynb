# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install openpyxl
import pandas as pd
file_path = '/content/drive/My Drive/Colab Databases/Student.xlsx'
df = pd.read_excel(file_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...

# %%
print(df.head())
# Out:
#    S.No. Semester                           Branch /Course  \
# 0    NaN      NaN                                      NaN
# 1    1.0    5CSA1  B.Tech - Computer Science & Engineering
# 2    2.0    5CSA1  B.Tech - Computer Science & Engineering
# 3    3.0    5CSA1  B.Tech - Computer Science & Engineering
# 4    4.0    5CSA1  B.Tech - Computer Science & Engineering
#
#   University Registration No. (Issued by R&S Branch)  \
# 0                                                NaN
# 1                                        22/FET/0062
# 2                                        22/FET/0063
# 3                                        22/FET/0064
# 4                                        22/FET/0065
#
#   Date of Admission in the Present Class/Course          Roll No.  \
# 0                                           NaN               NaN
# 1                                    29.07.2025  1/22/FET/BCS/002
# 2                                    29.07.2024  1/22/FET/BCS/003
# ...

# %%
df.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d.%m.%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#    S.No. Semester                           Branch /Course  \
# 0    NaN      NaN                                      NaN
# 1    1.0    5CSA1  B.Tech - Computer Science & Engineering
# 2    2.0    5CSA1  B.Tech - Computer Science & Engineering
# 3    3.0    5CSA1  B.Tech - Computer Science & Engineering
# 4    4.0    5CSA1  B.Tech - Computer Science & Engineering
#
#   University Registration No. (Issued by R&S Branch)  \
# 0                                                NaN
# 1                                        22/FET/0062
# 2                                        22/FET/0063
# 3                                        22/FET/0064
# ...

# %%
df
# Out:
# /usr/local/lib/python3.11/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d.%m.%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#     S.No. Semester                           Branch /Course  \
# 0     NaN      NaN                                      NaN
# 1     1.0    5CSA1  B.Tech - Computer Science & Engineering
# 2     2.0    5CSA1  B.Tech - Computer Science & Engineering
# 3     3.0    5CSA1  B.Tech - Computer Science & Engineering
# 4     4.0    5CSA1  B.Tech - Computer Science & Engineering
# ..    ...      ...                                      ...
# 58   58.0    5CSA2  B.Tech - Computer Science & Engineering
# 59   59.0    5CSA2  B.Tech - Computer Science & Engineering
# 60   60.0    5CSA1  B.Tech - Computer Science & Engineering
# 61   61.0    5CSA1  B.Tech - Computer Science & Engineering
# ...

# %%
df.loc[62]
# Out:
# S.No.                                                                                                   62.0
# Semester                                                                                               5CSA2
# Branch /Course                                                                                           NaN
# University Registration No. (Issued by R&S Branch)                                                       NaN
# Date of Admission in the Present Class/Course                                                            NaN
# Roll No.                                                                                        12401005M002
# Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN         YASH YADAV
# Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-FN                NaN
# Gender                                                                                                   NaN
# ...

# %%
df.iloc[62]
# Out:
# S.No.                                                                                                   62.0
# Semester                                                                                               5CSA2
# Branch /Course                                                                                           NaN
# University Registration No. (Issued by R&S Branch)                                                       NaN
# Date of Admission in the Present Class/Course                                                            NaN
# Roll No.                                                                                        12401005M002
# Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN         YASH YADAV
# Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-FN                NaN
# Gender                                                                                                   NaN
# ...

# %%
df.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d.%m.%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#    S.No. Semester                           Branch /Course  \
# 0    NaN      NaN                                      NaN
# 1    1.0    5CSA1  B.Tech - Computer Science & Engineering
# 2    2.0    5CSA1  B.Tech - Computer Science & Engineering
# 3    3.0    5CSA1  B.Tech - Computer Science & Engineering
# 4    4.0    5CSA1  B.Tech - Computer Science & Engineering
#
#   University Registration No. (Issued by R&S Branch)  \
# 0                                                NaN
# 1                                        22/FET/0062
# 2                                        22/FET/0063
# 3                                        22/FET/0064
# ...

# %%
df.tail()
# Out:
#     S.No. Semester                           Branch /Course  \
# 58   58.0    5CSA2  B.Tech - Computer Science & Engineering
# 59   59.0    5CSA2  B.Tech - Computer Science & Engineering
# 60   60.0    5CSA1  B.Tech - Computer Science & Engineering
# 61   61.0    5CSA1  B.Tech - Computer Science & Engineering
# 62   62.0    5CSA2                                      NaN
#
#    University Registration No. (Issued by R&S Branch)  \
# 58                                        22/FET/0117
# 59                                        22/FET/0118
# 60                                        22/FET/0256
# 61                                        21/SET/2097
# 62                                                NaN
#
#    Date of Admission in the Present Class/Course          Roll No.  \
# 58                                    29.07.2024  1/22/FET/BCS/063
# 59                                    29.07.2024  1/22/FET/BCS/064
# 60                                    29.07.2024  1/22/FET/BCS/434
# ...

# %%
df.describe()
# Out:
#            S.No.  Updated Mobile No. of Student  \
# count  62.000000                   6.100000e+01
# mean   31.500000                   8.748738e+09
# std    18.041619                   9.272586e+08
# min     1.000000                   6.206768e+09
# 25%    16.250000                   8.307323e+09
# 50%    31.500000                   8.920577e+09
# 75%    46.750000                   9.350647e+09
# max    62.000000                   9.910299e+09
#
#        Total Due Fee for Current Semester / (Previous semester if pending)  \
# count                                          61.000000
# mean                                         7828.192131
# std                                         39406.712974
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 19 columns):
#  #   Column                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                     --------------  -----
#  0   S.No.                                                                                      62 non-null     float64
#  1   Semester                                                                                   62 non-null     object
#  2   Branch /Course                                                                             61 non-null     object
#  3   University Registration No. (Issued by R&S Branch)                                         61 non-null     object
#  4   Date of Admission in the Present Class/Course                                              61 non-null     object
# ...

# %%
df.shape
# Out:
# (63, 19)

# %%
df.columns
# Out:
# Index(['S.No.', 'Semester', 'Branch /Course',
#        'University Registration No. (Issued by R&S Branch)',
#        'Date of Admission in the Present Class/Course', 'Roll No.',
#        'Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN',
#        'Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-FN',
#        'Gender', 'Religion', 'Category', 'Aadhaar No. of Student',
#        'Updated Mobile No. of Student', 'Updated E-mail ID', 'State',
#        'Total Due Fee for Current Semester / (Previous semester if pending)',
#        'Fee Paid for Current Semester / (Previous semester if pending)',
#        'mentors', 'Unnamed: 18'],
#       dtype='object')

# %%
df.dtypes
# Out:
# S.No.                                                                                        float64
# Semester                                                                                      object
# Branch /Course                                                                                object
# University Registration No. (Issued by R&S Branch)                                            object
# Date of Admission in the Present Class/Course                                                 object
# Roll No.                                                                                      object
# Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN     object
# Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-FN     object
# Gender                                                                                        object
# ...

# %%
df.isnull()
# Out:
#     S.No.  Semester  Branch /Course  \
# 0    True      True            True
# 1   False     False           False
# 2   False     False           False
# 3   False     False           False
# 4   False     False           False
# ..    ...       ...             ...
# 58  False     False           False
# 59  False     False           False
# 60  False     False           False
# 61  False     False           False
# 62  False     False            True
#
#     University Registration No. (Issued by R&S Branch)  \
# 0                                                True
# 1                                               False
# 2                                               False
# 3                                               False
# 4                                               False
# ..                                                ...
# 58                                              False
# 59                                              False
# ...

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [S.No., Semester, Branch /Course, University Registration No. (Issued by R&S Branch), Date of Admission in the Present Class/Course, Roll No., Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN, Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-FN, Gender, Religion, Category, Aadhaar No. of Student, Updated Mobile No. of Student, Updated E-mail ID, State, Total Due Fee for Current Semester / (Previous semester if pending), Fee Paid for Current Semester / (Previous semester if pending), mentors, Unnamed: 18]
# Index: []

# %%
df.fillna(0)
# Out:
#     S.No. Semester                           Branch /Course  \
# 0     0.0        0                                        0
# 1     1.0    5CSA1  B.Tech - Computer Science & Engineering
# 2     2.0    5CSA1  B.Tech - Computer Science & Engineering
# 3     3.0    5CSA1  B.Tech - Computer Science & Engineering
# 4     4.0    5CSA1  B.Tech - Computer Science & Engineering
# ..    ...      ...                                      ...
# 58   58.0    5CSA2  B.Tech - Computer Science & Engineering
# 59   59.0    5CSA2  B.Tech - Computer Science & Engineering
# 60   60.0    5CSA1  B.Tech - Computer Science & Engineering
# 61   61.0    5CSA1  B.Tech - Computer Science & Engineering
# 62   62.0    5CSA2                                        0
#
#    University Registration No. (Issued by R&S Branch)  \
# 0                                                   0
# 1                                         22/FET/0062
# 2                                         22/FET/0063
# ...

# %%
df.sort_values(by='Roll No.')
# Out:
# /usr/local/lib/python3.11/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d.%m.%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#     S.No. Semester                           Branch /Course  \
# 32   32.0    5CSA2  B.Tech - Computer Science & Engineering
# 61   61.0    5CSA1  B.Tech - Computer Science & Engineering
# 1     1.0    5CSA1  B.Tech - Computer Science & Engineering
# 2     2.0    5CSA1  B.Tech - Computer Science & Engineering
# 3     3.0    5CSA1  B.Tech - Computer Science & Engineering
# ..    ...      ...                                      ...
# 58   58.0    5CSA2  B.Tech - Computer Science & Engineering
# 59   59.0    5CSA2  B.Tech - Computer Science & Engineering
# 60   60.0    5CSA1  B.Tech - Computer Science & Engineering
# 62   62.0    5CSA2                                      NaN
# ...
